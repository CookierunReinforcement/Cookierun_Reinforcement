# %% [markdown]
# # 1. Install and Import Dependencies

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (2.1.1+cu118)
# Requirement already satisfied: torchvision in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (0.16.1+cu118)
# Requirement already satisfied: torchaudio in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (2.1.1+cu118)
# Requirement already satisfied: filelock in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (3.0)
# Requirement already satisfied: jinja2 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: numpy in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torchvision) (1.24.1)
# Requirement already satisfied: requests in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->torchvision) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install stable-baselines3[extra] protobuf==3.20.*
# Out:
# Requirement already satisfied: protobuf==3.20.* in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (3.20.3)
# Requirement already satisfied: stable-baselines3[extra] in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (1.24.1)
# Requirement already satisfied: torch>=1.13 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (2.1.1+cu118)
# Requirement already satisfied: cloudpickle in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: matplotlib in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (3.8.1)
# Requirement already satisfied: opencv-python in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Requirement already satisfied: pygame in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: psutil in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (13.6.0)
# Requirement already satisfied: shimmy~=1.1.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: pillow in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from stable-baselines3[extra]) (9.3.0)
# Requirement already satisfied: autorom~=0.6.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: ale-py~=0.8.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.59.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.0.0)
# Requirement already satisfied: six>1.9 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: filelock in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.9.0)
# Requirement already satisfied: sympy in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.0)
# Requirement already satisfied: jinja2 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.44.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: colorama in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (6.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %%
# !pip install mss pyautogui pytesseract
# Out:
# Requirement already satisfied: mss in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (9.0.1)
# Requirement already satisfied: pyautogui in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (0.9.54)
# Requirement already satisfied: pytesseract in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (0.3.10)
# Requirement already satisfied: pymsgbox in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: packaging>=21.3 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pytesseract) (9.3.0)
# Requirement already satisfied: pyrect in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium) (1.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium) (4.8.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gymnasium) (0.0.4)

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gym) (1.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (from gym) (0.0.8)

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\myfiles\programfiles\anaconda3\envs\cookie_reinforce\lib\site-packages (9.3.0)

# %%
# MSS for screen capture
from mss import mss
# Sending commands
import pyautogui
# Opencv for frame processing
import cv2
# Transformational framework
import numpy as np
# OCR for text extraction
import pytesseract
from PIL import Image
# Visualize captured frames
from matplotlib import pyplot as plt
#Bring in time for pauses
import time
# Environment components
from gymnasium import Env
from gymnasium.spaces import Box, Discrete

# %% [markdown]
# # 2. Build the Environment

# %% [markdown]
# ## 2.1 Create Environment

# %%
class CookieRun(Env):
  #Setup the environment action and observation shapes
  def __init__(self, monitor_num = 2):
    super().__init__()
    self.observation_space = Box(low=0, high=255, shape=(1,90,120), dtype=np.uint8)
    self.action_space = Discrete(3)

    self.cap = mss()
    mon = self.cap.monitors[monitor_num]
    # game window
    self.game_location = {"top": mon["top"] + 400, "left": mon["left"] + 500, 'width':1500, 'height':800, "mon": monitor_num}
    # gameover window
    self.done_location = {'top':260, 'left':780, 'width':337, 'height':344, "mon": monitor_num}
    file = cv2.imread('./done.png')
    self.img = cv2.cvtColor(file, cv2.COLOR_BGR2HSV)
    self.img_hist = cv2.calcHist([self.img], [0,1], None, [180,256], [0,180,0, 256])
    cv2.normalize(self.img_hist, self.img_hist, 0, 1, cv2.NORM_MINMAX)
    # reset x window
    self.x_location = {'top':192, 'left':1393, 'width':84, 'height':88, "mon": monitor_num}
    file = cv2.imread('./close.png')
    self.x_img = cv2.cvtColor(file, cv2.COLOR_BGR2HSV)
    self.x_img_hist = cv2.calcHist([self.x_img], [0,1], None, [180,256], [0,180,0, 256])
    cv2.normalize(self.x_img_hist, self.x_img_hist, 0, 1, cv2.NORM_MINMAX)
    # score window
    self.score_location = {'top':160, 'left':760, 'width':350, 'height':64}
    # health window
    self.health_location = {'top' : 88, 'left':509, 'width':1188, 'height':10}
    #Sliding parameter
    self.sliding = False
    #Reward parameter
    self.pre_reward = 1187
    self.invincible_time = 0


  # What is called to do, something in the game
  def step(self, action):
    #Action key - 0 : Idle / 1 : jump / 2 : slide
    action_map = {
        0:'idle',
        1:'jump',
        2:'slide'
    }
    if action == 1:
        if not(self.sliding):
            pyautogui.click(x=206, y=869)
    if action == 2:
        if self.sliding:
            pyautogui.mouseDown(x=1625, y=889)
        else:
            pyautogui.mouseUp(x=1625, y=889)
        self.sliding = not(self.sliding)

    #Checking whether game is done
    done, done_cap = self.get_done()
    #Get the next observation
    new_observation = self.get_observation()
    
    #set reward
    #current_score = np.array(self.cap.grab(self.score_location))
    #plt.imshow(current_score)
    #str = pytesseract.image_to_string(current_score,config='digits -c tessedit_char_whitelist=0123456789 -c tessedit_char_blacklist=\abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ,.\n')
    #str = str[2:]
    #if str:
    #    try:
    #        score = int(str)
    #        reward = (score - self.pre_reward)/1000
    #        self.pre_reward = score 
    #    except:
    #        reward = self.pre_reward/1000
    #else:
    #    reward = self.pre_reward/1000
    current_health = np.array(env.cap.grab(env.health_location))
    c = np.arange(0,1187,1)
    cnt = 0
    for a in c:
        if current_health[5][a][2] > 200:
            cnt += 1
    reward = 0
    if cnt - self.pre_reward <= -30:
        reward = -30
        self.invincible_time = 5
    elif self.invincible_time >0:
        reward = 0
        self.invincible_time = self.invincible_time - 1
    else:
        reward = 10
    if cnt != 0:
        self.pre_reward = cnt
        
    info = {'arg1':1}

    return new_observation, reward, done, False, info

  # Restart the game
  def reset(self, seed=None):
    time.sleep(15)
    pyautogui.click(x=908, y=936)
    time.sleep(1)
    pyautogui.click(x=908, y=936)
    time.sleep(6)
    pyautogui.click(x=1044, y=866)
    time.sleep(3)
    pyautogui.click(x=1044, y=866)
    time.sleep(1)
    x_cap = np.array(self.cap.grab(self.x_location))
    x_cap = cv2.cvtColor(x_cap, cv2.COLOR_BGR2HSV)
    x_hist = cv2.calcHist([x_cap], [0,1], None, [180,256], [0,180,0, 256])
    cv2.normalize(x_hist, x_hist, 0, 1, cv2.NORM_MINMAX)
    ret = cv2.compareHist(self.x_img_hist, x_hist, cv2.HISTCMP_CORREL)
    if ret > 0.9:
        pyautogui.click(x=1393, y=192)
        time.sleep(6)
    pyautogui.click(x=1534, y=900)
    time.sleep(1)
    pyautogui.click(x=1170, y=693)
    time.sleep(3.5)
    info = {'arg1':0}
    return self.get_observation(), info

  # Get the part of the obeservation of the game that we want
  def get_observation(self):
    # Get screen capture of game
    raw = np.array(self.cap.grab(self.game_location))[:,:,:3]
    rgb = cv2.cvtColor(raw, cv2.COLOR_BGR2RGB)
    
    # K-mean
    data = rgb.reshape(-1, 3).astype(np.float32)
    criteria = (cv2.TERM_CRITERIA_MAX_ITER + cv2.TERM_CRITERIA_EPS, 5, 0.1)
    retval, bestLabels, centers = cv2.kmeans(data, 5, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
    centers = centers.astype(np.uint8)
    dst = centers[bestLabels].reshape(rgb.shape)
       
       
    
    # Grayscale
    gray = cv2.cvtColor(raw, cv2.COLOR_BGR2GRAY)
    # resize
    resize = cv2.resize(dst, (120,90))
    # Add channels first
    #channel = np.reshape(resize, (1,90,120))
    
    
    return dst, resize

  # Get the gameover state - Use opencv2 to compare image
  def get_done(self):
    done_cap = np.array(self.cap.grab(self.done_location))
    done_cap = cv2.cvtColor(done_cap, cv2.COLOR_BGR2HSV)
    done_hist = cv2.calcHist([done_cap], [0,1], None, [180,256], [0,180,0, 256])
    cv2.normalize(done_hist, done_hist, 0, 1, cv2.NORM_MINMAX)
    done = False
    ret = cv2.compareHist(self.img_hist, done_hist, cv2.HISTCMP_CORREL)
    if ret > 0.9:
        done = True
        self.pre_reward = 1187
    return done, done_cap

# %%
x, y = pyautogui.position()
print(x, y)
# Out:
# 1704 473

# %% [markdown]
# ## 2.2 Test Environment

# %%
env= CookieRun(2)
temp1, temp2 = env.get_observation()
plt.imshow(temp1)

# %%
plt.imshow(temp2)

# %%
obs = env.get_observation()
done, done_cap = env.get_done()
print(done)
plt.imshow(done_cap)
# Out:
# (1600, 2560, 3)
# (1600, 2560)
# (90, 120)
# (1, 90, 120)
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# False

# %%
plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_GRAY2BGR))

# %%
current_score = np.array(env.cap.grab({'top':160, 'left':760, 'width':350, 'height':64}))
plt.imshow(current_score)
str = pytesseract.image_to_string(current_score,config='digits -c tessedit_char_whitelist=0123456789')
str = str[2:]
print("String is " + str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#
# File ~\anaconda3\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File ~\anaconda3\lib\subprocess.py:1440, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1439 try:
# -> 1440     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1441                              # no special security
#    1442                              None, None,
#    1443                              int(not close_fds),
#    1444                              creationflags,
#    1445                              env,
#    1446                              cwd,
#    1447                              startupinfo)
#    1448 finally:
#    1449     # Child is launched. Close the parent's copy of those pipe
#    1450     # handles that only the child should have open.  You need
#    (...)
#    1453     # pipe will not close when the child process exits and the
#    1454     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[69], line 3
#       1 current_score = np.array(env.cap.grab({'top':160, 'left':760, 'width':350, 'height':64}))
#       2 plt.imshow(current_score)
# ----> 3 str = pytesseract.image_to_string(current_score,config='digits -c tessedit_char_whitelist=0123456789')
#       4 str = str[2:]
#       5 print("String is " + str)
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
#     423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:288, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     277 with save(image) as (temp_name, input_filename):
#     278     kwargs = {
#     279         'input_filename': input_filename,
#     280         'output_filename_base': temp_name,
#    (...)
#     285         'timeout': timeout,
#     286     }
# --> 288     run_tesseract(**kwargs)
#     289     filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290     with open(filename, 'rb') as output_file:
#
# File ~\anaconda3\lib\site-packages\pytesseract\pytesseract.py:260, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     258         raise
#     259     else:
# --> 260         raise TesseractNotFoundError()
#     262 with timeout_manager(proc, timeout) as error_string:
#     263     if proc.returncode:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
env.reset()
obs,_,_,_,_ = env.step(1)
plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_GRAY2BGR))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[516], line 1
# ----> 1 env.reset()
#       2 obs,_,_,_,_ = env.step(1)
#       3 plt.imshow(cv2.cvtColor(obs[0], cv2.COLOR_GRAY2BGR))
#
# Cell In[513], line 95, in CookieRun.reset(self, seed)
#      94 def reset(self, seed=None):
# ---> 95   time.sleep(15)
#      96   pyautogui.click(x=908, y=936)
#      97   time.sleep(1)
#
# KeyboardInterrupt:

# %%
obs,_,_,_,_ = env.step(0)
plt.imshow(obs[0])

# %%
current_health = np.array(env.cap.grab(env.health_location))
plt.imshow(current_health)
c = np.arange(0,1187,1)
cnt = 0
for a in c:
    if current_health[5][a][2] < 200:
        cnt += 1
print(cnt)
# Out:
# 1187

# %% [markdown]
# # 3. Train the Model

# %% [markdown]
# ## 3.1 Create Callback

# %%
# Import os for file path management
import os
# Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback
# Check Environment
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ## 3.2 Build () and Train

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack

# %%
env = CookieRun()

# %%
model = DQN('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, buffer_size=120000, learning_starts=5, learning_rate = 0.001)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/DQN_16
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 3.25e+03 |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 5        |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 1666     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.36     |
# |    n_updates        | 37140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 457      |
# |    ep_rew_mean      | 3.59e+03 |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5        |
# |    time_elapsed     | 626      |
# |    total_timesteps  | 3657     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.08     |
# |    n_updates        | 37638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 3.56e+03 |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5        |
# |    time_elapsed     | 929      |
# |    total_timesteps  | 5504     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 38099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 3.41e+03 |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5        |
# |    time_elapsed     | 1200     |
# |    total_timesteps  | 7060     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.79     |
# |    n_updates        | 38488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 3.36e+03 |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5        |
# |    time_elapsed     | 1476     |
# |    total_timesteps  | 8664     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.89     |
# |    n_updates        | 38889    |
# ----------------------------------
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 model.learn(total_timesteps=1000000, callback=callback)
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\dqn\dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:312, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309 callback.on_training_start(locals(), globals())
#     311 while self.num_timesteps < total_timesteps:
# --> 312     rollout = self.collect_rollouts(
#     313         self.env,
#     314         train_freq=self.train_freq,
#     315         action_noise=self.action_noise,
#     316         callback=callback,
#     317         learning_starts=self.learning_starts,
#     318         replay_buffer=self.replay_buffer,
#     319         log_interval=log_interval,
#     320     )
#     322     if rollout.continue_training is False:
#     323         break
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:544, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     541 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     543 # Rescale and perform action
# --> 544 new_obs, rewards, dones, infos = env.step(actions)
#     546 self.num_timesteps += env.num_envs
#     547 num_collected_steps += 1
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:197, in VecEnv.step(self, actions)
#     190 """
#     191 Step the environments with the given action
#     192
#     193 :param actions: the action
#     194 :return: observation, reward, done, information
#     195 """
#     196 self.step_async(actions)
# --> 197 return self.step_wait()
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\anaconda3\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# Cell In[23], line 44, in CookieRun.step(self, action)
#      42 if action == 1:
#      43     if not(self.sliding):
# ---> 44         pyautogui.click(x=206, y=869)
#      45 if action == 2:
#      46     if self.sliding:
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File ~\anaconda3\lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1734         raise FailSafeException(
#    1735             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1736         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %% [markdown]
# # 4. Test out Model

# %%
model.load('train/best_model_130000')

# %%
for episode in range(5): 
    obs = env.reset()[0]
    total_reward = 0
    done = False
    while not done: 
        action, state = model.predict(obs)
        obs, reward, done, _, info = env.step(int(action))
        time.sleep(0.01)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(episode, total_reward))
# Out:
# Total Reward for episode 0 is 5160
# Total Reward for episode 1 is 4210
# Total Reward for episode 2 is 4520
# Total Reward for episode 3 is 4310
# Total Reward for episode 4 is 4980
